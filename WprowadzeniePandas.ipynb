# %%
import pandas as pd

# %% [markdown]
# ## Load dataset

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
iris.shape
# Out:
# (149, 5)

# %%
iris.dtypes
# Out:
# 5.1            float64
# 3.5            float64
# 1.4            float64
# 0.2            float64
# Iris-setosa     object
# dtype: object

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", 
                   names = ['sh', 'sw', 'ph', 'pw', 'name'])
iris
# Out:
#       sh   sw   ph   pw            name
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#                sh          sw          ph          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
iris.sh
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sh, Length: 150, dtype: float64

# %%
iris.sh[0:10]
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# 8    4.4
# 9    4.9
# Name: sh, dtype: float64

# %%
iris[0:10].sh
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# 8    4.4
# 9    4.9
# Name: sh, dtype: float64

# %%
iris[0:10][['sh', 'sw']]
# Out:
#     sh   sw
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %%
iris[['sh', 'sw']][5:10]
# Out:
#     sh   sw
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %%
iris.iloc[10:20, 1:3]
# Out:
#      sw   ph
# 10  3.7  1.5
# 11  3.4  1.6
# 12  3.0  1.4
# 13  3.0  1.1
# 14  4.0  1.2
# 15  4.4  1.5
# 16  3.9  1.3
# 17  3.5  1.4
# 18  3.8  1.7
# 19  3.8  1.5

# %%
iris.loc[10:20, ['sh', 'name']]
# Out:
#      sh         name
# 10  5.4  Iris-setosa
# 11  4.8  Iris-setosa
# 12  4.8  Iris-setosa
# 13  4.3  Iris-setosa
# 14  5.8  Iris-setosa
# 15  5.7  Iris-setosa
# 16  5.4  Iris-setosa
# 17  5.1  Iris-setosa
# 18  5.7  Iris-setosa
# 19  5.1  Iris-setosa
# 20  5.4  Iris-setosa

# %%
iris.at[0, 'sh'] = -200
iris
# Out:
#         sh   sw   ph   pw            name
# 0   -200.0  3.5  1.4  0.2     Iris-setosa
# 1      4.9  3.0  1.4  0.2     Iris-setosa
# 2      4.7  3.2  1.3  0.2     Iris-setosa
# 3      4.6  3.1  1.5  0.2     Iris-setosa
# 4      5.0  3.6  1.4  0.2     Iris-setosa
# ..     ...  ...  ...  ...             ...
# 145    6.7  3.0  5.2  2.3  Iris-virginica
# 146    6.3  2.5  5.0  1.9  Iris-virginica
# 147    6.5  3.0  5.2  2.0  Iris-virginica
# 148    6.2  3.4  5.4  2.3  Iris-virginica
# 149    5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Filtrowanie

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
import numpy as np

# %%
d = {'col1': [1, 2, 3], 'col2': [np.NaN, np.NaN, 4], 'col3': [np.NaN, 5, 6]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2  col3
# 0     1   NaN   NaN
# 1     2   NaN   5.0
# 2     3   4.0   6.0

# %%
df.dropna(thresh=2)
# Out:
#    col1  col2  col3
# 1     2   NaN   5.0
# 2     3   4.0   6.0

# %%
df[df['col3'].notnull()]
# Out:
#    col1  col2  col3
# 1     2   NaN   5.0
# 2     3   4.0   6.0

# %%
df[df[['col2', 'col3']].notnull().all(1)]
# Out:
#    col1  col2  col3
# 2     3   4.0   6.0

# %% [markdown]
# ## Pandas + Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
for name, group in iris.groupby('name'):
    print(name)
    group.hist()
    plt.show()
# Out:
# Iris-setosa
# Iris-versicolor
# Iris-virginica

# %%
to_save = pd.get_dummies(iris)
to_save
# Out:
#       sh   sw   ph   pw  name_Iris-setosa  name_Iris-versicolor  \
# 0    5.1  3.5  1.4  0.2                 1                     0
# 1    4.9  3.0  1.4  0.2                 1                     0
# 2    4.7  3.2  1.3  0.2                 1                     0
# 3    4.6  3.1  1.5  0.2                 1                     0
# 4    5.0  3.6  1.4  0.2                 1                     0
# ..   ...  ...  ...  ...               ...                   ...
# 145  6.7  3.0  5.2  2.3                 0                     0
# 146  6.3  2.5  5.0  1.9                 0                     0
# 147  6.5  3.0  5.2  2.0                 0                     0
# 148  6.2  3.4  5.4  2.3                 0                     0
# 149  5.9  3.0  5.1  1.8                 0                     0
#
#      name_Iris-virginica
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# ...

# %%
to_save.to_csv("iris_from_pandas.csv", index=False)
